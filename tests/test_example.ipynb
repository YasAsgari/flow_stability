# %%
cd
# Out:
# C:\Users\Yasaman

# %%
cd FLOW_STABILITY
# Out:
# C:\Users\Yasaman\FLOW_STABILITY

# %%
from src.flowstab.temporal_network import ContTempNetwork, ContTempInstNetwork
# Out:
# Could not load sparse_dot_mkl. Will use scipy.sparse for matrix products.

# %%
source_nodes=[0, 1, 1]
target_nodes=[1, 2, 3]
starting_times=[0, 1, 2]
ending_times=[2.5, 2.5, 2.5]
cont_net=ContTempNetwork(source_nodes=source_nodes, target_nodes=target_nodes, starting_times=starting_times, ending_times=ending_times)

# %%
A = cont_net.compute_static_adjacency_matrix(start_time=0, end_time=1.5)
A.todense()
# Out:
# matrix([[0. , 1.5, 0. , 0. ],
#         [1.5, 0. , 0.5, 0. ],
#         [0. , 0.5, 0. , 0. ],
#         [0. , 0. , 0. , 0. ]])

# %%
A = cont_net.compute_static_adjacency_matrix()
A.todense()
# Out:
# matrix([[0. , 2.5, 0. , 0. ],
#         [2.5, 0. , 1.5, 0.5],
#         [0. , 1.5, 0. , 0. ],
#         [0. , 0.5, 0. , 0. ]])

# %%
cont_net.node_array
# Out:
# array([0, 1, 2, 3])

# %%
cont_net.events_table
# Out:
#    source_nodes  target_nodes  starting_times  ending_times  durations
# 0             0             1               0           2.5        2.5
# 1             1             2               1           2.5        1.5
# 2             1             3               2           2.5        0.5

# %%
cont_net._compute_time_grid()

# %%
cont_net.time_grid
# Out:
#           is_start
# times id
# 0.0   0       True
# 1.0   1       True
# 2.0   2       True
# 2.5   0      False
#       1      False
#       2      False

# %%
import numpy as np

# %%
i,

# %%
cont_net._get_closest_time(t=1.5)
# Out:
# (1.0, 1)
